# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Data Source
# https://www.himalayandatabase.com/index.html
#
# ##### Guide
# https://www.himalayandatabase.com/downloads/HD%20Online%20Guide.pdf

# %% [markdown]
# ### Converting coordiantes  and clean

# %%
from coordinates.converter import convert_decimal_to_degrees, convert_degrees_to_decimal

# %%
df_peaks = pd.read_excel("./Himalayan Database/RawData/geoCodePeaks.xlsx", sheet_name="Original")

# %%
df_peaks = df_peaks.dropna(subset=['COORDS'])

# %%
df_peaks['lng'] = df_peaks.COORDS.apply(lambda x : x.split(", ")[0])
df_peaks['lat'] = df_peaks.COORDS.apply(lambda x : x.split(", ")[1])
# Out:
# <ipython-input-163-24928bf6d277>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_peaks['lng'] = df_peaks.COORDS.apply(lambda x : x.split(", ")[0])
# <ipython-input-163-24928bf6d277>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_peaks['lat'] = df_peaks.COORDS.apply(lambda x : x.split(", ")[1])

# %%
df_peaks['lng'] = df_peaks.apply(lambda x : convert_degrees_to_decimal( int(x.lng.split(" ")[0]), int(x.lng.split(" ")[1]), int(x.lng.split(" ")[2])) if x.to_convert==1 else x.lng, axis=1)
df_peaks['lat'] = df_peaks.apply(lambda x : convert_degrees_to_decimal( int(x.lat.split(" ")[0]), int(x.lat.split(" ")[1]), int(x.lat.split(" ")[2])) if x.to_convert==1 else x.lat, axis=1)
# Out:
# <ipython-input-164-a94821db6e38>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_peaks['lng'] = df_peaks.apply(lambda x : convert_degrees_to_decimal( int(x.lng.split(" ")[0]), int(x.lng.split(" ")[1]), int(x.lng.split(" ")[2])) if x.to_convert==1 else x.lng, axis=1)
# <ipython-input-164-a94821db6e38>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_peaks['lat'] = df_peaks.apply(lambda x : convert_degrees_to_decimal( int(x.lat.split(" ")[0]), int(x.lat.split(" ")[1]), int(x.lat.split(" ")[2])) if x.to_convert==1 else x.lat, axis=1)

# %%
df_peaks.photos = df_peaks.photos.apply(lambda x : np.nan if x==0 else x)
# Out:
# C:\Users\botiv\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_peaks[['peakid', "lng",'lat', 'photos']].to_csv("./Himalayan Database/RawData/geoCodePeaks_converted.csv", encoding="utf-8-sig")

# %% [markdown]
# ### Quick Geocode

# %%
#https://www.explorehimalaya.com/peak-climbing-resources/identified-peaks-of-nepal/
#https://www.culturaltreks.com/expedition-information/peak-openedfor-expedition-2.html
#https://peakvisor.com/adm/nepal.html

# %%
import googlemaps
import time
gmaps = googlemaps.Client(key="AIzaSyCiIeRfvwXuH55QS2X_ZtitS2H-5x01BwE") ## in gcp 
search_type = "mountain_peaks"
search_term = "mountain peaks"

r=50000
d=2*r

# %%
centers = [[
          86.57501220703125,
          27.659203644307926
        ],
        [
          83.81469726562499,
          28.618281599983852
        ],
        [
          81.09832763671875,
          29.64509464986076
        ],
          [
            87.99774169921875,
            27.727298422724655
          ],
          [
            87.60223388671875,
            27.741884632507087
          ],
          [
            87.17926025390625,
            27.702983735525862
          ],
          [
            86.80023193359374,
            27.805068967813085
          ],
          [
            86.54205322265625,
            27.97984914504167
          ],
          [
            86.19598388671875,
            27.819644755099446
          ],
          [
            85.7208251953125,
            27.822073862795612
          ],
          [
            85.55877685546875,
            28.02592458049937
          ],
          [
            85.1934814453125,
            28.16645387574049
          ],
          [
            84.87762451171875,
            28.36723539252299
          ],
          [
            84.451904296875,
            28.533861572281154
          ],
          [
            84.13604736328125,
            28.7965462417692
          ],
          [
            83.58673095703125,
            28.98411731593083
          ],
          [
            83.15826416015625,
            29.20252099881366
          ],
          [
            82.66937255859375,
            29.499378142743375
          ],
          [
            82.320556640625,
            29.726222319395504
          ],
          [
            81.92230224609375,
            29.890662187739487
          ],
          [
            81.5185546875,
            30.130875412002318
          ],
          [
            80.9967041015625,
            30.230594564932193
          ],
          [
            80.51055908203125,
            30.230594564932193
          ],
          [
            79.99969482421875,
            30.44867367928756
          ],
          [
            79.4146728515625,
            30.64736425824319
          ]
        ]

# %%
df_All = pd.DataFrame()
for c in centers:

    places_result = gmaps.places_nearby(location=str(c[1]) + ", " + str(c[0]), radius=r, keyword=search_term)
    df_page1 = pd.DataFrame(places_result["results"])
    df = df_page1
    try:   
        time.sleep(2)
        places_result = gmaps.places_nearby(page_token = places_result['next_page_token'])
        print('Paged')
        df_page2 = pd.DataFrame(places_result["results"])
        df = pd.concat([df_page1,df_page2])
        try:
            time.sleep(2)
            places_result = gmaps.places_nearby(page_token = places_result['next_page_token'])
            print('Paged')
            df_page3 = pd.DataFrame(places_result["results"])
            df = pd.concat([df_page1,df_page2, df_page3])
        except KeyError:
            pass
    except KeyError:
        pass

    try:
        df['lat'] = df.geometry.apply(lambda x  : x['location']['lat'])
        df['lng'] = df.geometry.apply(lambda x  : x['location']['lng'])
    except AttributeError:
        pass
   
    df_All = pd.concat([df_All,df])
    print(f'Completed - peaks: {len(df)}')
# Out:
# Paged
# Paged
# Completed - peaks: 55
# Paged
# Completed - peaks: 40
# Completed - peaks: 4
# Paged
# Completed - peaks: 28
# Completed - peaks: 7
# Paged
# Paged
# Completed - peaks: 47
# Paged
# Paged
# Completed - peaks: 58
# Paged
# Paged
# Completed - peaks: 55
# Completed - peaks: 15
# Completed - peaks: 12
# Paged
# Completed - peaks: 31
# Completed - peaks: 16
# Completed - peaks: 16
# Completed - peaks: 19
# Paged
# Completed - peaks: 34
# Paged
# Completed - peaks: 26
# Completed - peaks: 4
# Completed - peaks: 6
# Completed - peaks: 5
# Completed - peaks: 4
# Completed - peaks: 3
# Completed - peaks: 7
# Paged
# Completed - peaks: 31
# Paged
# Paged
# Completed - peaks: 51
# Paged
# Paged
# Completed - peaks: 54

# %%
df_All.drop_duplicates(subset='place_id').to_csv("./Himalayan Database/RawData/google_places_res.csv", encoding="utf-8-sig")

# %% [markdown]
# Nepal Himal Peak Profile site

# %%
#https://nepalhimalpeakprofile.org/peak-profile/all-peaks

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# %%
# Out:
# '/sagarmatha'

# %%
session = requests.Session()
retry = Retry(connect=3, backoff_factor=0.5)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)

def find_lat_lon(link):
    try:
        page = requests.get("https://nepalhimalpeakprofile.org" + link)
        soup = BeautifulSoup(page.text, 'html.parser')    
        print(link)
        return [soup.find('img', {'src' : '/images/icon/longitude.svg'}).next_element.next_element.find('div', {'class' : 'el-content uk-panel uk-margin-small-top'}).text, soup.find('img', {'src' : '/images/icon/latitude.svg'}).next_element.next_element.find('div', {'class' : 'el-content uk-panel uk-margin-small-top'}).text]
     
    except:
        return [np.nan, np.nan]

# %%
np.nan
# Out:
# nan

# %%
#pd.read_json("./Himalayan Database/RawData/coords data/nepalHimalpeaksData.json", orient='records' , encoding="utf8",lines=True)
df_nepal_himal = pd.read_csv("./Himalayan Database/RawData/coords data/nepalHimalpeaksData.csv")

# %%
df_nepal_himal['coords'] = df_nepal_himal.links.apply(lambda x : find_lat_lon(x.strip()))
# Out:
# /sagarmatha
# /kanchenjunga-main
# /lho-tse
# /yalung-khang
# /kanchenjunga-central
# /kanchenjunga-south
# /makalu-i
# /lho-tse-middle
# /lho-tse-shar
# /cho-oyu
# /dhaulagiri-i
# /manaslu
# /annapurna-i
# /yalung-khang-west
# /gyachung-khang
# /kanchenjunga-north
# /annapurna-ii
# /tenzing-peak
# /khangbachen
# /himal-chuli-east
# /harka-gurung-chuli
# /nup-tse
# /makalu-south-east
# /khambachen-east
# /dhaulagiri-ii
# /ngojumba-khang
# /dhaulagiri-iii
# /kumbhakarna
# /hillary-peak
# /makalu-ii
# /dhaulagiri-iv
# /varaha-shikhar
# /dhaulagiri-v
# /shanti-shikhar
# /khangsar-khang-west
# /annapurna-iii
# /himal-chuli-west
# /annapurna-iv
# /khangsar-khang
# /jongsang-peak
# /shartse-ii
# /gangapurna
# /ganesh-i
# /kabru-central
# /churen
# /churen-west
# /kirat-chuli
# /pasang-lhamu-chuli
# /gimigela-chuli
# /talung
# /nemjung
# /himal-chuli-north
# /chamlang
# /kabru
# /nagpai-gosum-i
# /nagpai-gosum-ii
# /dhaulagiri-vi
# /dome-khang
# /putha-hiun-chuli
# /kabru-north
# /langtang-lirung
# /annapurna-south
# /langtang-ri
# /tarke-khang
# /gurja-himal
# /chamar
# /nepal-peak
# /chamar-north
# /pumo-ri
# /manaslu-north
# /nepal-peak-ii
# /gangapurna-west
# /gaurishankar
# /tilicho-peak
# /api
# /barun-tse
# /ratna-chuli
# /himlung-himal
# /pathibhara-chuli
# /ganesh-ii
# /ganesh-iii
# /nampa-chuli
# /api-west
# /himjung
# /janak-chuli
# /sharphu-i
# /nilgiri-north
# /thulagi-peak
# /ganesh-iv
# /gyajikang
# /saipal
# /hunchhi
# /nepal-gyap-peak
# /ganesh-v
# /lamjung-himal
# /gauri
# /kang-garu
# /leonpo-gang
# /dorje-lyakpa
# /langpo-peak
# /anidesh-chuli
# /chabuk
# /numbur
# /burke-khang
# /nilgiri-central
# /tengi-ragi-tau
# /chota-ri
# /himlung-east
# /loshar-i
# /tukuche-peak
# /rongshar-ri-i
# /lugula
# /chago
# /gurkarpo-ri
# /panbari
# /sharphu-iii
# /drohmo
# /kanjiroba-main
# /saipal-east
# /pathibhara-south-east
# /pem-thang-karpo-ri
# /yangra-south
# /nupla-khang
# /loshar-ii
# /chumbu
# /kanti-himal
# /kanjiroba-north
# /pathibhara-north-east
# /jethi-bahurani-chuli
# /pandra
# /amphu-i
# /nilgiri-south
# /chumbu-north
# /ohmi-khang
# /pathibhara-east
# /cheo-himal
# /ama-dablam
# /khangri-shar
# /bobaye-chuli
# /bhairav-takura
# /khangtega
# /ghanyala-hies
# /khangri-west
# /thakar-go
# /kyashar
# /phu-khang-go-panbari-north
# /hongu
# /tutse
# /thaknak-ri
# /nampa
# /chang-himal
# /firankof-west
# /gurans
# /pethangtse
# /khang-nachu-go
# /peak-4
# /jasemba-go
# /leonpo-gang-east
# /lachama-chuli
# /likhu-chuli-i
# /pangbuk-ri
# /lingtren
# /cho-polu
# /dzanye-i
# /tharke-khang
# /salbachum
# /chako
# /nampa-ii
# /khumjung-himal
# /firankof-east
# /phu-khang
# /paniyotippa
# /hulang-go
# /cho-buje
# /sherson-north-west
# /rathong
# /numri
# /agole-east
# /baudha-himal
# /sobithongie
# /jobo-rinjang
# /rolwaling-khang
# /likhu-chuli-2
# /peak-41
# /khang-karpo
# /phole
# /yarwa
# /khumbutse
# /dhaulagari
# /phurbi-chyachu
# /lachama-north
# /kande-hiun-chuli
# /thamserku
# /changdi
# /putha-west
# /pangri-goldumba
# /pangpoche-i
# /langmoche-ri
# /kanjerawa
# /sita-chuchura
# /thoche-go
# /ramtang
# /kyunga-ri-i
# /putha-shoulder
# /raksha-urai
# /friendship-peak
# /chulu-east
# /khatang
# /chhib-himal
# /jomsom-himal
# /changla-khang
# /phu-khang-north
# /nampa-south
# /dhagpache
# /chaw-east
# /malangphulang
# /pethangtse-east
# /ghenye-liru
# /kambong
# /changla
# /tso-karpo-khang
# /hongde
# /tripura-hiun-chuli
# /nangamari-i
# /yangri
# /karyolung
# /ghustung-north
# /mariyang
# /mt-lama
# /rolwaling-khang-north
# /phunge
# /phungi
# /surma-sarovar-north
# /tso-karpo
# /kanti-east
# /kyunga-ri-ii
# /pangpoche-ii
# /rongshar-ri-ii
# /tawoche
# /singu-chuli
# /purbung
# /tengkhangpoche
# /pangbuk-north
# /khatung-khang
# /yakwa-khang
# /ganesh-vi
# /bhrikuti
# /langchung-khang
# /jarkya-peak
# /mera-peak
# /ghustung-south
# /mahalangur-peak
# /yanme-khang-south-east
# /mariyang-west
# /sharphu-ii
# /patrasi
# /mayung-thang-khang
# /kanchauni
# /kojichwa-chuli
# /hiun-chuli
# /sharphu-iv
# /yaupa
# /langju
# /chola-tse
# /sherson
# /chulu-west
# /larkya-peak
# /lhashamma
# /langshisha-ri
# /swaksa-khang
# /chaw-peak
# /yoko-pahad
# /bamon-go
# /tsartse
# /lhayul-peak
# /takphu-himal
# /amotsang-himal
# /jyachhung
# /saldim-west
# /kasi-dalpha
# /tashi-khang
# /manapathi
# /ganchenpo
# /saldim
# /til-khang
# /chhuama-peak-i
# /bhrikuti-shail
# /gyala
# /kusum-kanguru
# /kang-kuru
# /danga
# /pokhar-khang
# /saribung
# /nangamari-north-west
# /pamalka
# /taple-shikhar
# /ombigaichan
# /merra
# /samdo-peak
# /dolma-khang
# /kyabura
# /omi-tso-go
# /kaipuchonam-main
# /changdi-east
# /sharphu-v
# /langdung
# /chhuama-peak-ii
# /dzanye-ii
# /dogari-south
# /tankya-i
# /pama-himal
# /peri-himal
# /khang-tokal
# /tankya-ii
# /chaw-far-west
# /pharchamo
# /takla-khang
# /kanti-central
# /kogi-khang-north
# /tsisima
# /asajya-tuppa
# /nyalu
# /pankar-himal
# /kojichwa-south
# /chhuama-peak-iii
# /tankya-iii
# /chhochenphu-himal
# /chukyima-go
# /senup
# /ganglung-gangri-i
# /tankya-iv
# /gorakh-khang
# /pabuk-khang
# /simnang-himal
# /mansail-south
# /dingjung-north
# /dingjung-ri
# /gandharva-chuli
# /chaw-west
# /mansail
# /naulekh
# /yara-chuli
# /saula
# /changla-khang-north-west
# /raungsiyar
# /sat-peak
# /langdak
# /chungen-changma
# /kaipuchonam-north-west
# /tengkoma
# /ek-rate-danda
# /rhimbu
# /nangamari-ii
# /sanctuary-peak
# /yanme-khang
# /mustang-himal
# /lasa
# /kekyap-ri-i
# /mansail-east
# /khayang
# /thakmorpa-ri
# /pota-north
# /swelo-khang
# /chhuama-peak-iv
# /pashuwo
# /peri
# /dwijen-himal
# /jabou-ri
# /imjatse
# /nirekha
# /palchung-i
# /thakar-go-east
# /kyazo-ri
# /gyalzen-peak
# /bhemdang-ri
# /urkenmang
# /kokthang
# /takphu-north
# /yasa-thak
# /chhochenphu-north
# /shey-shikhar
# /lobuje-west
# /mustang-himal-ii
# /purkung
# /changwathang
# /bedding-go
# /cheki-go
# /hunku-chuli
# /yolungma-khang
# /bokta
# /jabou-ri-north
# /bijora-hiun-chuli
# /jijang
# /gaugiri
# /chhopa-bamare
# /danfe-shail
# /bhulu-lhasa
# /tobsar
# /lung-sampa
# /ghyun-himal-i
# /chandi-himal
# /kogi-khang
# /kaipuchonam-west
# /gorakha-himal
# /pisang
# /lobuje-east
# /mukot-himal
# /kwangde
# /sharphu-vi
# /lhonak
# /mera-south
# /khangchung-uiaa-peak
# /keshang-khang-uaaa-peak
# /nalakankar
# /jyanglatunpu-peak
# /rolmi
# /asajya-tuppa-west
# /aichyn
# /punchen-himal
# /yubra-himal
# /dudh-kundali
# /nupchu-peak
# /abi
# /lungchhung
# /araniko-chuli
# /ardang
# /mojka-peak
# /ghyun-himal-ii
# /ghyun-himal-iii
# /palchung-ii
# /khung
# /dhechyan-khang
# /phari-lapcha
# /karko
# /thapa-peak
# /kekyap-ri-ii
# /ghodchadi
# /palchung-iii
# /norbu-kang
# /tilje
# /tinje-peak
# /thakmorpa-north-east
# /khaptang
# /lapuchun
# /kagmara
# /suyaokhang
# /nobuk
# /nheserku
# /samjang
# /kangfu-gaton-kanta-gaton
# /paldor-peak
# /ramdong-go
# /chanabolo
# /yarsang-khang
# /jyangche
# /ghyambu-peak
# /nimku
# /ghanja-la-chuli
# /baden-powell-scout-peak
# /sisne-ii
# /sisne
# /khongma-tse
# /lunadhar-khang
# /thorong-peak
# /nar-phu
# /chhukung-chuli
# /kap-chuli
# /dogari-himal

# %%
df_nepal_himal['lat'] = df_nepal_himal.coords.apply(lambda x : x[0])

df_nepal_himal['lon'] = df_nepal_himal.coords.apply(lambda x : x[1])

# %%
df_nepal_himal.to_csv("./Himalayan Database/RawData/coords data/nepalHimalpeaksDataCoords.csv", encoding="utf-8-sig")

# %%
df_nepal_himal.links.apply(lambda x : x)
# Out:
# 0                 /sagarmatha
# 1          /kanchenjunga-main
# 2                    /lho-tse
# 3               /yalung-khang
# 4       /kanchenjunga-central
#                 ...
# 463             /thorong-peak
# 464                  /nar-phu
# 465           /chhukung-chuli
# 466                /kap-chuli
# 467             /dogari-himal
# Name: links, Length: 468, dtype: object
